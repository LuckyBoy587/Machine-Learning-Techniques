# %% [markdown]
# <span style="font-size:30px"><B>Pandas Library<B></span>

# %%
import numpy as np
import pandas as pd

# %%
from sklearn.datasets import fetch_california_housing

# %%
housedataset=fetch_california_housing()

# %%
print(housedataset)
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#           37.88      , -122.23      ],
#        [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#           37.86      , -122.22      ],
#        [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#           37.85      , -122.24      ],
#        ...,
#        [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#           39.43      , -121.22      ],
#        [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#           39.43      , -121.32      ],
#        [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
# ...

# %%
type(housedataset)
# Out:
# sklearn.utils._bunch.Bunch

# %% [markdown]
# <span style="font-size:30px"><B>Pandas Dataframe<B></span>

# %%
housedf=pd.DataFrame(housedataset.data,columns=housedataset.feature_names)

# %%
housedf.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
housedf.shape
# Out:
# (20640, 8)

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("mathchi/diabetes-data-set")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\kowsh\.cache\kagglehub\datasets\mathchi\diabetes-data-set\versions\1

# %% [markdown]
# <span style="font-size:20px"><b>Importing the data from csv file to a pandas dataframe</b></span>

# %%
#csv file to pandas Dataframe
diabetes_df=pd.read_csv(path + "/diabetes.csv")

# %%
type(diabetes_df)
# Out:
# pandas.core.frame.DataFrame

# %%
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes_df.shape
# Out:
# (768, 9)

# %% [markdown]
# creating a Dataframe using random values

# %%
randomdf=pd.DataFrame(np.random.rand(20,10))
randomdf.shape
# Out:
# (20, 10)

# %%
randomdf.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.583004  0.516056  0.402555  0.931168  0.574603  0.874384  0.217195
# 1  0.760340  0.046858  0.075202  0.495774  0.319223  0.439028  0.111446
# 2  0.519303  0.588312  0.532871  0.062594  0.305890  0.160878  0.162813
# 3  0.565437  0.483101  0.389564  0.941728  0.760762  0.910563  0.863653
# 4  0.852608  0.678961  0.609051  0.837139  0.774781  0.753818  0.397753
#
#           7         8         9
# 0  0.501450  0.245027  0.147901
# 1  0.766622  0.209979  0.095194
# 2  0.906316  0.524524  0.991651
# 3  0.277359  0.745857  0.588678
# 4  0.670169  0.905308  0.223147

# %%
#Finding the number of missing values
diabetes_df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
#counting the values based on the labels
diabetes_df.value_counts('Outcome')
#diabetes_df['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %% [markdown]
# ![image.png](attachment:18e375d5-e0e8-43e6-8594-a43bebc77fb5.png)

# %%
path = kagglehub.dataset_download("yasserh/student-marks-dataset")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\kowsh\.cache\kagglehub\datasets\yasserh\student-marks-dataset\versions\1

# %%
markdata_df=pd.read_csv(path + "/Student_Marks.csv")

# %%
markdata_df.shape
# Out:
# (100, 3)

# %%
print(markdata_df)
# Out:
#     number_courses  time_study   Marks
# 0                3       4.508  19.202
# 1                4       0.096   7.734
# 2                4       3.133  13.811
# 3                6       7.909  53.018
# 4                8       7.811  55.299
# ..             ...         ...     ...
# 95               6       3.561  19.128
# 96               3       0.301   5.609
# 97               4       7.163  41.444
# 98               7       0.309  12.027
# 99               3       6.335  32.357
#
# [100 rows x 3 columns]

# %%
markdata_df.columns=["Roll","attendance","mark"]

# %%
print(markdata_df)
# Out:
#     Roll  attendance    mark
# 0      3       4.508  19.202
# 1      4       0.096   7.734
# 2      4       3.133  13.811
# 3      6       7.909  53.018
# 4      8       7.811  55.299
# ..   ...         ...     ...
# 95     6       3.561  19.128
# 96     3       0.301   5.609
# 97     4       7.163  41.444
# 98     7       0.309  12.027
# 99     3       6.335  32.357
#
# [100 rows x 3 columns]

# %% [markdown]
# <b> Statistical Measures<b>

# %%
#count or number of values
markdata_df.count()
# Out:
# Roll          100
# attendance    100
# mark          100
# dtype: int64

# %%
diabetes_df.count()
# Out:
# Pregnancies                 768
# Glucose                     768
# BloodPressure               768
# SkinThickness               768
# Insulin                     768
# BMI                         768
# DiabetesPedigreeFunction    768
# Age                         768
# Outcome                     768
# dtype: int64

# %%
#Mean value column wise
diabetes_df.mean()
# Out:
# Pregnancies                   3.845052
# Glucose                     120.894531
# BloodPressure                69.105469
# SkinThickness                20.536458
# Insulin                      79.799479
# BMI                          31.992578
# DiabetesPedigreeFunction      0.471876
# Age                          33.240885
# Outcome                       0.348958
# dtype: float64

# %%
#Standard Deviation column wise
diabetes_df.std()
# Out:
# Pregnancies                   3.369578
# Glucose                      31.972618
# BloodPressure                19.355807
# SkinThickness                15.952218
# Insulin                     115.244002
# BMI                           7.884160
# DiabetesPedigreeFunction      0.331329
# Age                          11.760232
# Outcome                       0.476951
# dtype: float64

# %%
#Minimum vlaue
diabetes_df.min()
# Out:
# Pregnancies                  0.000
# Glucose                      0.000
# BloodPressure                0.000
# SkinThickness                0.000
# Insulin                      0.000
# BMI                          0.000
# DiabetesPedigreeFunction     0.078
# Age                         21.000
# Outcome                      0.000
# dtype: float64

# %%
#Maximum value
diabetes_df.max()
# Out:
# Pregnancies                  17.00
# Glucose                     199.00
# BloodPressure               122.00
# SkinThickness                99.00
# Insulin                     846.00
# BMI                          67.10
# DiabetesPedigreeFunction      2.42
# Age                          81.00
# Outcome                       1.00
# dtype: float64

# %%
# All the statistical Measures about the dataframe
diabetes_df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
# Adding a column to a Dataframe
housedf['Price']=housedataset.target

# %%
housedf.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  Price
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422

# %%
housedf.shape
# Out:
# (20640, 9)

# %%
#Removing a row
#drop() does NOT modify the dataframe permanently
#It returns a new dataframe
newhousedf=housedf.drop(index=0,axis=0)
newhousedf.shape
# Out:
# (20639, 9)

# %%
newhousedf.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# 5  4.0368      52.0  4.761658   1.103627       413.0  2.139896     37.85
#
#    Longitude  Price
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422
# 5    -122.25  2.697

# %%
#Removing a column
newhousedf.drop(columns='MedInc',axis=1,inplace=True)   #Now the original dataframe is modified.
newhousedf.head()
# Out:
#    HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  Longitude  \
# 1      21.0  6.238137   0.971880      2401.0  2.109842     37.86    -122.22
# 2      52.0  8.288136   1.073446       496.0  2.802260     37.85    -122.24
# 3      52.0  5.817352   1.073059       558.0  2.547945     37.85    -122.25
# 4      52.0  6.281853   1.081081       565.0  2.181467     37.85    -122.25
# 5      52.0  4.761658   1.103627       413.0  2.139896     37.85    -122.25
#
#    Price
# 1  3.585
# 2  3.521
# 3  3.413
# 4  3.422
# 5  2.697

# %%
# Locating a row using the index value
housedf.iloc[2]
# Out:
# MedInc          7.257400
# HouseAge       52.000000
# AveRooms        8.288136
# AveBedrms       1.073446
# Population    496.000000
# AveOccup        2.802260
# Latitude       37.850000
# Longitude    -122.240000
# Price           3.521000
# Name: 2, dtype: float64

# %%
# Locating a particular Column
housedf.iloc[:,0]    # first column
# Out:
# 0        8.3252
# 1        8.3014
# 2        7.2574
# 3        5.6431
# 4        3.8462
#           ...
# 20635    1.5603
# 20636    2.5568
# 20637    1.7000
# 20638    1.8672
# 20639    2.3886
# Name: MedInc, Length: 20640, dtype: float64

# %%
# Locating a particular Column
housedf.iloc[:,-1]    # Last column
# Out:
# 0        4.526
# 1        3.585
# 2        3.521
# 3        3.413
# 4        3.422
#          ...
# 20635    0.781
# 20636    0.771
# 20637    0.923
# 20638    0.847
# 20639    0.894
# Name: Price, Length: 20640, dtype: float64

# %%
#Correlation
housedf.corr()
# Out:
#               MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc      1.000000 -0.119034  0.326895  -0.062040    0.004834  0.018766
# HouseAge   -0.119034  1.000000 -0.153277  -0.077747   -0.296244  0.013191
# AveRooms    0.326895 -0.153277  1.000000   0.847621   -0.072213 -0.004852
# AveBedrms  -0.062040 -0.077747  0.847621   1.000000   -0.066197 -0.006181
# Population  0.004834 -0.296244 -0.072213  -0.066197    1.000000  0.069863
# AveOccup    0.018766  0.013191 -0.004852  -0.006181    0.069863  1.000000
# Latitude   -0.079809  0.011173  0.106389   0.069721   -0.108785  0.002366
# Longitude  -0.015176 -0.108197 -0.027540   0.013344    0.099773  0.002476
# Price       0.688075  0.105623  0.151948  -0.046701   -0.024650 -0.023737
#
#             Latitude  Longitude     Price
# MedInc     -0.079809  -0.015176  0.688075
# HouseAge    0.011173  -0.108197  0.105623
# AveRooms    0.106389  -0.027540  0.151948
# AveBedrms   0.069721   0.013344 -0.046701
# ...
